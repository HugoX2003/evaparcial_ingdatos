# %% [markdown]
# # Ing. Datos Parcial | Márquez Diestra, Hugo

# %% [markdown]
# ## Carga de datos

# %% [markdown]
# ### 1. Cargar los datos del dataset en un DataFrame (1 pt)

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/VehiculosElectricos.csv')
df
# Out:
#         VIN (1-10)    Condado          Ciudad Estado  CodigoPostal  AñoModelo  \
# 0       WBY8P6C58K       King         Seattle     WA       98115.0     2019.0
# 1       5YJSA1DN4D     Kitsap       Bremerton     WA       98312.0     2013.0
# 2       5YJSA1E26J       King            Kent     WA       98042.0     2018.0
# 3       WBY2Z2C54E       King        Bellevue     WA       98004.0     2014.0
# 4       5YJXCDE23J       King        Bellevue     WA       98004.0     2018.0
# ...            ...        ...             ...    ...           ...        ...
# 186874  JTMEB3FVXM  Snohomish       Arlington     WA       98223.0     2021.0
# 186875  7SAYGAEEXP  Snohomish        Stanwood     WA       98292.0     2023.0
# 186876  3FA6P0SUXK       King          Auburn     WA       98001.0     2019.0
# 186877  7SAYGDEE1P     Pierce          Tacoma     WA       98422.0     2023.0
# 186878  7SAYGDEE1R    Douglas  East Wenatchee     WA       98802.0     2024.0
#
# ...

# %% [markdown]
# ### 2. Segmentar el DataFrame y recuperar: desde el registro 50 hasta el registro 55 (1 pt)

# %%
df[50:56]
# Out:
#     VIN (1-10)   Condado     Ciudad Estado  CodigoPostal  AñoModelo   Marca  \
# 50  KNDCC3LGXK      King     Burien     WA       98146.0     2019.0     KIA
# 51  1N4AZ0CP1G      King   Kirkland     WA       98034.0     2016.0  NISSAN
# 52  5YJXCBE40H      King    Bothell     WA       98011.0     2017.0   TESLA
# 53  1N4AZ0CP6F      King   Bellevue     WA       98007.0     2015.0  NISSAN
# 54  JTJAAAAB7P  Thurston    Olympia     WA       98506.0     2023.0   LEXUS
# 55  5UXTS1C01M  Thurston  Rochester     WA       98579.0     2021.0     BMW
#
#      Modelo                   TipoVehiculoElectrico  \
# 50     NIRO          Battery Electric Vehicle (BEV)
# 51     LEAF          Battery Electric Vehicle (BEV)
# 52  MODEL X          Battery Electric Vehicle (BEV)
# 53     LEAF          Battery Electric Vehicle (BEV)
# 54       RZ          Battery Electric Vehicle (BEV)
# 55       X3  Plug-in Hybrid Electric Vehicle (PHEV)
#
# ...

# %% [markdown]
# ### 3. Listar los últimos 10 registros (0.5 pt)

# %%
df.tail(10)
# Out:
#                                                VIN (1-10)    Condado  \
# 186869                                         KM8KN4AE4P      Grant
# 186870                                         5YJSA1E55P     Pierce
# 186871                                         7SAYGDEF1P       King
# 186872                                         7SAYGDEF3P  Snohomish
# 186873  7SAYGDEE0N,Okanogan,Winthrop,WA,98862,2022,TES...        NaN
# 186874                                         JTMEB3FVXM  Snohomish
# 186875                                         7SAYGAEEXP  Snohomish
# 186876                                         3FA6P0SUXK       King
# 186877                                         7SAYGDEE1P     Pierce
# 186878                                         7SAYGDEE1R    Douglas
#
#                 Ciudad Estado  CodigoPostal  AñoModelo    Marca      Modelo  \
# 186869          Quincy     WA       98848.0     2023.0  HYUNDAI     IONIQ 5
# ...

# %% [markdown]
# ### 4. Mostrar 5 registros aleatorios (0.5 pt)

# %%
df.sample(5)
# Out:
#         VIN (1-10)    Condado            Ciudad Estado  CodigoPostal  \
# 134013  KL8CK6S03G  Snohomish             Brier     WA       98036.0
# 114604  7SAYGDEF1P       King           Seattle     WA       98105.0
# 5745    5YJ3E1EB2J       King              Kent     WA       98031.0
# 42434   5YJ3E1EB0L     Kitsap      Port Orchard     WA       98367.0
# 185241  5YJ3E1EA2J     Pierce  University Place     WA       98467.0
#
#         AñoModelo      Marca   Modelo           TipoVehiculoElectrico  \
# 134013     2016.0  CHEVROLET    SPARK  Battery Electric Vehicle (BEV)
# 114604     2023.0      TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 5745       2018.0      TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 42434      2020.0      TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 185241     2018.0      TESLA  MODEL 3  Battery Electric Vehicle (BEV)
#
#        ElegibilidadVehiculoCombustibleAlernativoLimpio(CAFV)  \
# 134013            Clean Alternative Fuel Vehicle Eligible
# ...

# %% [markdown]
# ### 5. Mostrar la información del DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186879 entries, 0 to 186878
# Data columns (total 17 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   VIN (1-10)                                             186879 non-null  object
#  1   Condado                                                186457 non-null  object
#  2   Ciudad                                                 186457 non-null  object
#  3   Estado                                                 186460 non-null  object
#  4   CodigoPostal                                           186457 non-null  float64
#  5   AñoModelo                                              186460 non-null  float64
#  6   Marca                                                  186460 non-null  object
#  7   Modelo                                                 186460 non-null  object
# ...

# %% [markdown]
# ### 6. Mostrar la estadística Resumen de la columna 'AutonomiaElectrica' (0.5 pt)

# %%
df['AutonomiaElectrica'].describe()
# Out:
# count    186460.000000
# mean         56.706328
# std          90.781987
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          73.000000
# max         337.000000
# Name: AutonomiaElectrica, dtype: float64

# %% [markdown]
# ## Limpieza de Datos:

# %% [markdown]
# ### 7. Verificar si el DataFrame tiene valores Nulos (NaN), y mostrar la cantidad de estos por cada columna

# %%
# Verificar si tiene valores nulos
df.isnull()
# Out:
#         VIN (1-10)  Condado  Ciudad  Estado  CodigoPostal  AñoModelo  Marca  \
# 0            False    False   False   False         False      False  False
# 1            False    False   False   False         False      False  False
# 2            False    False   False   False         False      False  False
# 3            False    False   False   False         False      False  False
# 4            False    False   False   False         False      False  False
# ...            ...      ...     ...     ...           ...        ...    ...
# 186874       False    False   False   False         False      False  False
# 186875       False    False   False   False         False      False  False
# 186876       False    False   False   False         False      False  False
# 186877       False    False   False   False         False      False  False
# 186878       False    False   False   False         False      False  False
#
#         Modelo  TipoVehiculoElectrico  \
# ...

# %%
# Mostrar cantidad por cada columna
df.isnull().sum()
# Out:
# VIN (1-10)                                                 0
# Condado                                                  422
# Ciudad                                                   422
# Estado                                                   419
# CodigoPostal                                             422
# AñoModelo                                                419
# Marca                                                    419
# Modelo                                                   419
# TipoVehiculoElectrico                                    419
# ElegibilidadVehiculoCombustibleAlernativoLimpio(CAFV)    419
# AutonomiaElectrica                                       419
# BaseMSRP                                                 419
# DistritoLegislativo                                      822
# IDVehiculo-DOL                                           419
# UbicacionVehiculo                                        427
# ...

# %%
# Total de valores nulos
df.isnull().sum().sum()
# Out:
# 7130

# %% [markdown]
# ### 8. Realizar la limpieza de datos de los Valores Nulos (NaN):
# #### - Considerando los datos (información) contenidos en las diversas columnas.
# #### - Considerando los tipos de datos.
# ### Mantener los cambios realizados en el DataFrame.

# %%
df.dropna(axis=0)
# Out:
#         VIN (1-10)    Condado          Ciudad Estado  CodigoPostal  AñoModelo  \
# 0       WBY8P6C58K       King         Seattle     WA       98115.0     2019.0
# 1       5YJSA1DN4D     Kitsap       Bremerton     WA       98312.0     2013.0
# 2       5YJSA1E26J       King            Kent     WA       98042.0     2018.0
# 3       WBY2Z2C54E       King        Bellevue     WA       98004.0     2014.0
# 4       5YJXCDE23J       King        Bellevue     WA       98004.0     2018.0
# ...            ...        ...             ...    ...           ...        ...
# 186874  JTMEB3FVXM  Snohomish       Arlington     WA       98223.0     2021.0
# 186875  7SAYGAEEXP  Snohomish        Stanwood     WA       98292.0     2023.0
# 186876  3FA6P0SUXK       King          Auburn     WA       98001.0     2019.0
# 186877  7SAYGDEE1P     Pierce          Tacoma     WA       98422.0     2023.0
# 186878  7SAYGDEE1R    Douglas  East Wenatchee     WA       98802.0     2024.0
#
# ...

# %% [markdown]
# ## Análisis de Datos:

# %% [markdown]
# ### 9. Mostrar los vehículos que tienen Autonomía Eléctrica mayor a 150 Km y el modelo del año 2019

# %%
ad1 = df[(df['AutonomiaElectrica'] > 150) & (df['AñoModelo'] == 2019)]
ad1
# Out:
#         VIN (1-10)    Condado      Ciudad Estado  CodigoPostal  AñoModelo  \
# 0       WBY8P6C58K       King     Seattle     WA       98115.0     2019.0
# 15      KNDCC3LGXK       King    Kirkland     WA       98033.0     2019.0
# 20      5YJ3E1EB9K       King     Seattle     WA       98177.0     2019.0
# 50      KNDCC3LGXK       King      Burien     WA       98146.0     2019.0
# 62      5YJXCBE29K       King        Kent     WA       98042.0     2019.0
# ...            ...        ...         ...    ...           ...        ...
# 186610  WA1LAAGE9K     Island    Freeland     WA       98249.0     2019.0
# 186661  WA1LAAGE1K     Pierce  Gig Harbor     WA       98332.0     2019.0
# 186698  5YJ3E1EA1K       King        Kent     WA       98032.0     2019.0
# 186745  5YJ3E1EA0K  Snohomish    Mukilteo     WA       98275.0     2019.0
# 186820  5YJ3E1EB0K  Snohomish     Edmonds     WA       98026.0     2019.0
#
#         Marca   Modelo           TipoVehiculoElectrico  \
# ...

# %% [markdown]
# ### 10. Mostrar la cantidad de vehículos por Marca

# %%
# Cantidad de vehículos por marca
dfmarca = df['Marca'].value_counts()

ad2 = dfmarca.sort_values(ascending=False)
ad2
# Out:
# Marca
# TESLA                   83191
# NISSAN                  14162
# CHEVROLET               14016
# FORD                     9788
# KIA                      7875
# BMW                      7850
# TOYOTA                   6742
# VOLKSWAGEN               5279
# JEEP                     4916
# HYUNDAI                  4778
# RIVIAN                   4524
# VOLVO                    4396
# AUDI                     3799
# CHRYSLER                 3273
# MERCEDES-BENZ            1735
# PORSCHE                  1162
# MITSUBISHI                987
# MINI                      941
# POLESTAR                  895
# SUBARU                    857
# HONDA                     841
# FIAT                      784
# DODGE                     614
# MAZDA                     549
# LEXUS                     506
# CADILLAC                  486
# LINCOLN                   274
# SMART                     260
# LUCID                     249
# JAGUAR                    232
# GENESIS                   204
# ...

# %% [markdown]
# ### 11. Mostrar la cantidad de vehículos eléctricos de la marca BMW en Seattle y mostrarlos registros

# %%
# Marca BMW y ciudad Seattle
dfbmwseattle = df[(df['Marca']=='BMW')&(df['Ciudad']=='Seattle')]

# %%
# Cantidad
ad3 = dfbmwseattle.shape[0]
ad3
# Out:
# 1671

# %%
dfbmwseattle
# Out:
#         VIN (1-10) Condado   Ciudad Estado  CodigoPostal  AñoModelo Marca  \
# 0       WBY8P6C58K    King  Seattle     WA       98115.0     2019.0   BMW
# 5       WBY33AW0XP    King  Seattle     WA       98109.0     2023.0   BMW
# 32      WBY8P4C50K    King  Seattle     WA       98177.0     2019.0   BMW
# 36      5UXTA6C07M    King  Seattle     WA       98116.0     2021.0   BMW
# 44      WBY1Z6C36H    King  Seattle     WA       98109.0     2017.0   BMW
# ...            ...     ...      ...    ...           ...        ...   ...
# 185989  WBY1Z4C56E    King  Seattle     WA       98118.0     2014.0   BMW
# 186194  WBY43AW00P    King  Seattle     WA       98107.0     2023.0   BMW
# 186229  WBY8P2C58K    King  Seattle     WA       98144.0     2019.0   BMW
# 186275  5UXTA6C02N    King  Seattle     WA       98115.0     2022.0   BMW
# 186624  WB523CF07R    King  Seattle     WA       98115.0     2024.0   BMW
#
#        Modelo                   TipoVehiculoElectrico  \
# ...

# %% [markdown]
# ### 12. Agrupar el DataFrame por Marca de vehículo y calcular el promedio de Autonomía Eléctrica

# %%
# Agrupar por Marca y calcular promedio Autonomía Eléctrica
dfmv = df.groupby('Marca')['AutonomiaElectrica'].mean()

dfmv
# Out:
# Marca
# ALFA ROMEO               33.000000
# AUDI                     48.113188
# AZURE DYNAMICS           56.000000
# BENTLEY                  19.666667
# BMW                      33.729554
# CADILLAC                  6.395062
# CHEVROLET                94.607092
# CHRYSLER                 32.191873
# DODGE                    32.000000
# FIAT                     85.637755
# FISKER                    1.987952
# FORD                     10.164794
# GENESIS                   0.000000
# GMC                       0.000000
# HONDA                    46.212842
# HYUNDAI                  19.025743
# JAGUAR                  203.741379
# JEEP                     22.352522
# KIA                      42.787302
# LAND ROVER               25.035088
# LEXUS                    21.320158
# LINCOLN                  23.478102
# LUCID                     0.000000
# MAZDA                    25.763206
# MERCEDES-BENZ             9.006340
# MINI                     17.604676
# ...

# %% [markdown]
# ### 13. Agrupar el DataFrame por Marca de vehículo y mostrar la estadística resumen de la columna Autonomía Eléctrica

# %%
dfmverae = df.groupby('Marca')['AutonomiaElectrica'].describe()
dfmverae
# Out:
#                         count        mean         std    min    25%    50%  \
# Marca
# ALFA ROMEO               47.0   33.000000    0.000000   33.0   33.0   33.0
# AUDI                   3799.0   48.113188   79.974781    0.0    0.0   16.0
# AZURE DYNAMICS            8.0   56.000000    0.000000   56.0   56.0   56.0
# BENTLEY                   3.0   19.666667    2.309401   17.0   19.0   21.0
# BMW                    7850.0   33.729554   36.421687    0.0    0.0   22.0
# CADILLAC                486.0    6.395062   13.948221    0.0    0.0    0.0
# CHEVROLET             14016.0   94.607092  104.532812    0.0    0.0   53.0
# CHRYSLER               3273.0   32.191873    0.393834   32.0   32.0   32.0
# DODGE                   614.0   32.000000    0.000000   32.0   32.0   32.0
# FIAT                    784.0   85.637755    1.494615   84.0   84.0   87.0
# FISKER                  166.0    1.987952    7.875538    0.0    0.0    0.0
# ...
